# %%
from isn.startup import *
# Out:
# I Wed-15:50:48.447: **************************************** Bluesky Startup
# I Wed-15:50:48.628: Starting Instrument with iconfig: /home/beams43/STAFF19ID/bluesky-mic/src/isn/configs/iconfig.yml
# Below are the IPython logging settings for your session.
# These settings have no impact on your experiment.
#
# Activating auto-logging. Current session state plus future input saved.
# Filename       : /home/beams43/STAFF19ID/bluesky-mic/notebooks/.logs/ipython_log.py
# Mode           : rotate
# Output logging : True
# Raw input log  : False
# Timestamping   : True
# State          : active
# Exception reporting mode: Plain
#
# End of IPython settings
# I Wed-15:50:51.364: **************************************** Bluesky Startup
# /home/beams/STAFF19ID/.conda/envs/eaa/lib/python3.11/site-packages/IPython/core/magics/logging.py:130: UserWarning: Couldn't start log: Log file is already active: /home/beams43/STAFF19ID/bluesky-mic/notebooks/.logs/ipython_log.py
# ...

# %%
RE(sim_count_plan())
RE(sim_rel_scan_plan())
# detectors = [tetramm4.current_1]
# Out:
# sim_rel_scan_plan(): sim_motor.position=np.float64(0.0).
# sim_rel_scan_plan(): sim_det.read()=OrderedDict([('noisy_det', {'value': np.float64(9999.994449351887), 'timestamp': 1751489570.8880188})]).
# sim_rel_scan_plan(): sim_det.read_configuration()=OrderedDict([('noisy_det_Imax', {'value': 10000, 'timestamp': 1751489570.900952}), ('noisy_det_center', {'value': 0, 'timestamp': 1751489570.901108}), ('noisy_det_sigma', {'value': 1, 'timestamp': 1751489570.9015927}), ('noisy_det_noise', {'value': 'uniform', 'timestamp': 1751489570.9015315}), ('noisy_det_noise_multiplier', {'value': 0.1, 'timestamp': 1751489451.0476863})]).
# sim_rel_scan_plan(): sim_det.noise._enum_strs=('none', 'poisson', 'uniform').
# ('99eb9cb1-4f0f-47f9-b92d-5526dfa039e7',)
# CA.Client.Exception...............................................
# ...
#     Context: "isnpc05.xray.aps.anl.gov:38361"
#     Source File: ../cac.cpp line 1238
#     Current Time: Wed Jul 02 2025 16:22:00.435481162
# ...

# %%
RE(bp.count(detectors, num=3))
# Out:
# E Wed-15:24:43.387: Run aborted
# Traceback (most recent call last):
#   File "/home/beams/STAFF19ID/.conda/envs/eaa/lib/python3.11/site-packages/bluesky/run_engine.py", line 1621, in _run
#     msg = self._plan_stack[-1].send(resp)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/beams/STAFF19ID/.conda/envs/eaa/lib/python3.11/site-packages/apstools/plans/labels_to_streams.py", line 231, in label_stream_wrapper
#     return (yield from bpp.plan_mutator(plan, action[when.value]))
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/beams/STAFF19ID/.conda/envs/eaa/lib/python3.11/site-packages/bluesky/preprocessors.py", line 188, in plan_mutator
#     raise ex
#   File "/home/beams/STAFF19ID/.conda/envs/eaa/lib/python3.11/site-packages/bluesky/preprocessors.py", line 141, in plan_mutator
#     msg = plan_stack[-1].send(ret)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
RE(sim_print_plan())
# Out:
# sim_print_plan(): This is a test.
# sim_print_plan():  sim_motor.position=0  sim_det.read()=OrderedDict([('noisy_det', {'value': 10000.009396349387, 'timestamp': 1741049440.972367})]).
# ()

# %%
from .utils.dm_utils import *
# Out:
# Traceback (most recent call last):
#
#   Cell In[10], line 1
#     from .utils.dm_utils import *
#
# ImportError: attempted relative import with no known parent package
