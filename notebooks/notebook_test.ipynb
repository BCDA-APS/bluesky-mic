# %%
from mic_instrument.startup import *
# Out:
# I Mon-18:25:08.565: APS DM environment file: /home/dm_id/etc/dm.setup.sh
# I Mon-18:25:08.568: APS DM workflow owner: 2ide
# Exception reporting mode: Plain
#
# End of IPython settings
# I Mon-18:25:16.470: Databroker catalog: temp
# I Mon-18:25:16.484: using ophyd control layer: 'pyepics'
# I Mon-18:25:17.945: /home/beams43/STAFF19ID/bluesky_gyl/bluesky-mic/src/instrument/devices/utils.py
# I Mon-18:25:17.946: /home/beams43/STAFF19ID/bluesky_gyl/bluesky-mic/src/instrument/devices/save_data.py
# I Mon-18:25:17.950: /home/beams43/STAFF19ID/bluesky_gyl/bluesky-mic/src/instrument/devices/xspress3.py
# I Mon-18:25:17.952: /home/beams43/STAFF19ID/bluesky_gyl/bluesky-mic/src/instrument/devices/scan_record.py
# I Mon-18:25:17.956: /home/beams43/STAFF19ID/bluesky_gyl/bluesky-mic/src/instrument/devices/area_det_hdf.py
# I Mon-18:25:18.048: /home/beams43/STAFF19ID/bluesky_gyl/bluesky-mic/src/instrument/devices/data_management.py
# ...

# %%
RE(sim_count_plan(10))
# Out:
# Transient Scan ID: 1     Time: 2025-03-03 18:50:40
# Persistent Unique Scan ID: '1b3a9790-4a84-419e-892c-0b56ee28d0ce'
# New stream: 'primary'
# +-----------+------------+------------+
# |   seq_num |       time |  noisy_det |
# +-----------+------------+------------+
# |         1 | 18:50:40.4 |  10000.091 |
# |         2 | 18:50:40.5 |   9999.904 |
# |         3 | 18:50:40.6 |   9999.969 |
# |         4 | 18:50:40.6 |  10000.088 |
# |         5 | 18:50:40.7 |   9999.975 |
# |         6 | 18:50:40.7 |   9999.932 |
# |         7 | 18:50:40.8 |  10000.089 |
# |         8 | 18:50:40.8 |   9999.995 |
# |         9 | 18:50:40.9 |  10000.074 |
# |        10 | 18:50:40.9 |  10000.009 |
# +-----------+------------+------------+
# generator count ['1b3a9790'] (scan num: 1)
# ('1b3a9790-4a84-419e-892c-0b56ee28d0ce',)

# %%
RE(sim_print_plan())
# Out:
# sim_print_plan(): This is a test.
# sim_print_plan():  sim_motor.position=0  sim_det.read()=OrderedDict([('noisy_det', {'value': 10000.009396349387, 'timestamp': 1741049440.972367})]).
# ()

# %%
from .utils.dm_utils import *
# Out:
# Traceback (most recent call last):
#
#   Cell In[10], line 1
#     from .utils.dm_utils import *
#
# ImportError: attempted relative import with no known parent package
